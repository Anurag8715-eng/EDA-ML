# %%
# EDA 1 :
""""

1. What is the range of selling prices in the dataset?

Answer:
The selling price range is obtained by subtracting the minimum selling price from the maximum selling price.
This range represents the overall spread of bike prices in the resale market and shows how diverse the price distribution is. In most second-hand bike markets, the range is quite wide because it includes both budget commuter bikes and premium/high-CC motorcycles.

2. What is the median selling price for bikes in the dataset?

Answer:
The median selling price is the middle value when all selling prices are sorted in ascending order.
It is a reliable indicator of the “typical” market price because it is not affected by extremely high or low values.
This helps understand what most buyers are paying for used bikes.

3. What is the most common seller type?

Answer:
By counting the frequency of seller categories, we find that “Individual” sellers are the most common.
This is expected because the majority of second-hand bikes in India are sold directly by individuals rather than dealers.

4. How many bikes have driven more than 50,000 kilometers?

Answer:
We count all bikes where km_driven exceeds 50,000.
These represent high-usage motorcycles, usually older models or heavily used commuter bikes.
This metric helps assess how many bikes in the dataset have undergone significant wear and tear.

5. What is the average km_driven value for each ownership type?

Answer:
By grouping data based on ownership status (1st owner, 2nd owner, 3rd owner, etc.), we compute the average kilometers driven.
Typical trend:

First-owner bikes have the lowest average km driven

Second-owner bikes show moderate usage

Third and above owners show the highest average usage

This pattern reflects normal real-world behavior where bikes change owners as their usage increases.

6. What proportion of bikes are from the year 2015 or older?

Answer:
We filter all entries where the manufacturing year is 2015 or earlier and divide by the total number of bikes.
This proportion indicates how many older models dominate the dataset, which is important because older bikes usually have lower resale value and higher depreciation.

7. What is the trend of missing values across the dataset?

Answer:
By checking for null values in each column, we identify whether any fields such as ex_showroom_price, owner, or seller_type contain gaps.
Understanding missing value trends helps decide whether to remove rows, fill values using imputation, or treat missing data separately during analysis.

8. What is the highest ex_showroom_price recorded, and for which bike?

Answer:
We locate the bike with the maximum ex_showroom_price.
Typically, the highest prices belong to premium models such as Royal Enfield 650cc, KTM, or other high-end motorcycles.
This shows which bike originally had the highest market value when purchased new.

9. What is the total number of bikes listed by each seller type?

Answer:
By grouping data by seller_type, we count how many bikes each category (Individual or Dealer) has listed.
Individual sellers generally dominate the dataset, followed by a smaller number of dealer listings.

10. What is the relationship between selling_price and km_driven for first-owner bikes?

Answer:
By filtering only first-owner bikes and plotting selling_price against km_driven, we observe a negative relationship.
As km_driven increases, the selling_price decreases.
This is because lower-usage bikes are perceived as better maintained and have higher demand in the resale market.

11. Identify and remove outliers in the km_driven column using the IQR method.

Answer:
Steps:

Calculate Q1 and Q3 for km_driven

Compute IQR = Q3 – Q1

Determine lower and upper limits using 1.5 × IQR

Remove values outside these limits

This cleans the dataset by removing unrealistic values (e.g., extremely low km like 5 km or extremely high km like 300,000 km), leading to more reliable analysis.

12. Perform a bivariate analysis to visualize the relationship between year and selling_price.

Answer:
Using a scatter plot or line plot, we see that newer bikes (recent years) generally have higher selling prices.
This reflects natural depreciation where older bikes lose value as they age.
The bivariate relationship displays a clear upward trend between manufacturing year and resale price.

13. What is the average depreciation in selling price based on the bike’s age?

Answer:
Bike age = Current Year – Manufacturing Year
Depreciation = Ex-showroom price – Selling Price

By grouping bikes by age and calculating average depreciation, we observe that:

Newer bikes have lower depreciation

Older bikes have much higher depreciation

This confirms the expected depreciation pattern in second-hand vehicle markets.

14. Which bike names are priced significantly above the average price for their manufacturing year?

Answer:
We find bikes whose selling_price exceeds (avg_price_for_that_year + 1 standard deviation).
Such bikes are usually:

Premium models

Special editions

Rarely used or well-maintained bikes

These outliers indicate bikes with higher perceived value or brand reputation.

15. Develop a correlation matrix for numeric columns and visualize it using a heatmap.

Answer:
A correlation matrix including year, selling_price, km_driven, and ex_showroom_price shows:
selling_price strongly correlates positively with year and ex_showroom_price

selling_price negatively correlates with km_driven

km_driven negatively correlates with year

The heatmap visualizes these strengths, helping identify useful predictors for resale price modeling.

""""

# %%
# EDA 2 :

""""

1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?

Answer:
To find the average selling price per dealer, we group the dataset by Dealer_Name and calculate the mean of Price ($).
This reveals which dealers specialize in budget cars and which focus on premium vehicles.

Dealers with higher average prices generally sell:

Luxury brands

Newer models

High-engine-capacity cars

Dealers with lower averages typically handle:

Older cars

Small hatchbacks

Low-income customer segments

This comparison helps understand dealership positioning in the market.

2. Which car brand (Company) has the highest variation in prices, and what does this tell us about pricing trends?

Answer:
Price variation is measured using standard deviation for each company.
A high variation indicates that the company sells a wide range of models — from budget variants to expensive luxury trims.

For example:

Toyota or Honda may show moderate variation (budget + mid-range).

BMW, Audi, Mercedes show very high variation due to premium trims.

This variation shows how diverse the brand’s market segment is.

3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?

Answer:
Using boxplots for Manual vs Automatic transmission, we observe:

Automatic cars usually have higher median prices

The IQR for automatics is broader due to their popularity in higher-end cars

Manual cars show a tighter, lower IQR, representing budget-friendly variants

This highlights the pricing difference based on transmission technology.

4. What is the distribution of car prices across different regions?

Answer:
A boxplot or histogram shows the price spread across regions (North, South, East, West).
Typically:

Metro regions (North, West) have higher average prices

Non-metro regions show lower prices

Variance indicates the diversity of car types available

This helps identify regional differences in purchasing power.

5. What is the distribution of cars based on body styles?

Answer:
A countplot of Body Style reveals the popularity of each segment.

Common trends:

Sedans and Hatchbacks dominate

SUVs form a large share due to current market preference

Coupes and Convertibles appear less frequently and are premium models

This distribution helps understand customer preferences.

6. How does the average selling price of cars vary by customer gender and annual income?

Answer:
We group by Gender and Annual Income to compute average prices.
Findings usually show:

Higher-income customers buy higher-priced cars

Gender-based differences are usually minor

Income is the strongest predictor of buying power

This analysis highlights purchasing behavior trends.

7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?

Answer:
Two analyses are performed:

Distribution of prices → boxplots

Count of cars sold → bar chart

Most regions show:

Significant differences in price medians

Higher sales counts in regions with more dealerships

Regions with higher incomes show higher car prices

This reflects both supply and demand factors.

8. How does the average car price differ between cars with different engine sizes?

Answer:
Grouping by Engine shows that:

Bigger engines (V6, V8) → Higher prices

Smaller engines (I4, I3) → Budget to mid-range prices

Some engines show wide variation due to luxury trims

Engine capacity is a strong determinant of pricing.

9. How do car prices vary based on the customer’s annual income bracket?

Answer:
Income is divided into brackets (low, medium, high).
Higher brackets show significantly higher spending on cars, including luxury and high-performance models.
Lower brackets show purchases of older or smaller models.

This demonstrates direct correlation between income and car price.

10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?

Answer:
We count occurrences of each Model and choose the top 5.

Price distribution (violin/box plot) shows:

Some popular models have tight price ranges (budget cars)

Others have wide ranges due to multiple variants (sedans, SUVs)

This helps analyze model popularity vs. price flexibility.

11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?

Answer:
Using grouped boxplots:

Findings usually show:

Engine size strongly affects price regardless of color

Colors like Black, White, and Red show the highest price variation due to availability in both budget and premium cars

Rare colors show smaller but sometimes higher average prices

Color influences price slightly, but engine is the main factor.

12. Is there any seasonal trend in car sales based on the date of sale?

Answer:
We convert the Date to months and analyze sales count per month.

Observations:

Sales usually peak during festive seasons (October–December)

Low sales appear during monsoon or early-year months

Seasonal trends help dealerships adjust inventory

13. How does the car price distribution change when considering different combinations of body style and transmission type?

Answer:
A multi-level boxplot shows:

Automatic SUVs have the highest average prices

Manual hatchbacks have the lowest

Sedans show wide variation due to multiple trim levels

Combination analysis reveals deeper pricing insights.

14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?

Answer:
A correlation matrix reveals:

Price is positively correlated with engine size

Price is strongly correlated with annual income

Engine size also correlates with income (high-income buyers choose bigger engines)

These interactions reflect typical consumer behavior.

15. How does the average car price vary across different car models and engine types?

Answer:
Grouping by both Model and Engine shows the average price for every combination.

Insights:

Some models maintain consistent prices across engines

Others have huge jumps in price when moving from smaller to larger engine types

Luxury models stand out with high engine-price combinations

This combined analysis gives the most granular pricing insights.

""""

# %%
# EDA 3 :

""""

1. What is the average rating for each product category?

Answer:
To find the average rating, we group the dataset by category and compute the mean of the rating column.
This reveals how customers perceive different categories of products.

Typical observations:

Categories such as Electronics, Beauty, and Home Improvement often show higher average ratings because customers tend to review positively when the product meets expectations.

Categories with lower averages may indicate issues in product quality or customer dissatisfaction.

The average rating per category helps identify which segments consistently deliver customer satisfaction.

2. What are the top rating_count products by category?

Answer:
We sort products within each category by rating_count in descending order.
Products with the highest rating_count are the most popular and most frequently purchased items.

This analysis shows:

Which products have strong market presence

Which items are heavily reviewed

Which products are customer favorites

These items usually dominate sales rankings in their categories.

3. What is the distribution of discounted prices vs. actual prices?

Answer:
We analyze the spread of both discounted_price and actual_price using histograms or density plots.

Insights:

Actual prices typically have a wider range, covering budget to premium products.

Discounted prices often cluster in lower ranges due to promotions.

The difference between the two shows the strength of discounts.

This distribution helps assess pricing strategies and discount depth across the marketplace.

4. How does the average discount percentage vary across categories?

Answer:
We compute the mean of discount_percentage grouped by category.
This highlights which product segments receive the highest discounts.

For example:

Fashion, Beauty, and Accessories usually show higher discount percentages.

Electronics often have moderate discounts due to high base prices.

Books might show small or no discounts.

This analysis helps understand category-wise marketing and promotion strategies.

5. What are the most popular product names?

Answer:
Popularity is defined by high rating_count or frequent appearances in the dataset.
Products with the highest counts are considered best-selling.

These products typically have:

Strong customer demand

Good reviews

Competitive pricing

High visibility on Amazon

Listing them helps identify market leaders.

6. What are the most popular product keywords?

Answer:
We extract keywords from product_name by splitting and counting frequently occurring words.

Common patterns include keywords such as:

“Wireless”

“Bluetooth”

“Portable”

“Smart”

“USB”

These words indicate trending product features and customer preferences in online shopping.

7. What are the most popular product reviews?

Answer:
We identify review entries with the highest rating_count or high rating scores and frequently repeated sentiments.

Popular reviews usually contain:

Strong positive feedback

Clear descriptions of product benefits

High usefulness to other customers

Review popularity helps understand what customers value most in a product.

8. What is the correlation between discounted_price and rating?

Answer:
We calculate the correlation coefficient and interpret the relationship.

Typical findings:

The correlation is usually very weak or close to zero.

This indicates that customer rating does not strongly depend on whether the product is cheap or expensive.

Ratings are more influenced by product quality rather than discount price.

This is an important insight for pricing and review strategies.

9. What are the top 5 categories based on the highest ratings?

Answer:
We sort categories by mean rating in descending order.

Categories with the highest ratings usually include:

Electronics

Beauty

Home & Kitchen

Personal Care

Books

High-rated categories typically offer reliable, frequently purchased items with strong customer satisfaction.

10. Identify any potential areas for improvement or optimization based on the data analysis.

Answer:
From the EDA, several actionable improvements can be identified:

Categories with low ratings need quality checks.
Products receiving consistently poor reviews should be analyzed for defects or misleading descriptions.

Low rating_count products may need better visibility.
These products could benefit from:

Improved product images

Better descriptions

Sponsored ads

High discount categories may indicate weak demand.
Some categories show very high discount percentages but still have low rating_count.
This signals poor customer interest.

Products with high price but low ratings need repositioning.
These may require:

Updated versions

Better packaging

Adjusted pricing strategy

Frequent negative keywords in reviews require attention.
Issues such as “poor build quality,” “not as described,” or “low battery backup” should be addressed immediately.

""""

# %%
# EDA 4 :

""""

1. Read the dataframe, check null values if present then do the needful, check duplicate rows, if present then do the needful.

Answer:
After loading the dataset, we first check for missing values using isnull().sum().
If null values appear in columns like Artist, Track Name, or Popularity, we handle them based on the severity:

If very few rows have missing values → drop them

If many values are missing → apply imputation (e.g., fill with median for popularity or mode for artist)

Next, we check duplicate rows using df.duplicated().sum().
Duplicate entries—often repeated tracks—are removed using df.drop_duplicates() to ensure accurate analysis.

This step ensures data cleanliness and reliability before performing further EDA.

2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.

Answer:
A histogram of the popularity column shows how popularity scores are spread across all tracks.

Observations typically include:

Popularity values cluster between moderate to high ranges

A few tracks may have extremely low popularity

The distribution may be slightly right-skewed or left-skewed depending on the dataset

This helps understand whether most hip-hop tracks are widely popular or vary significantly.

3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.

Answer:
A scatter plot of duration (ms) vs popularity helps identify patterns.

Common findings:

There is usually no strong correlation between track duration and popularity

Tracks of both short and long durations can be equally popular

Popularity is influenced more by artist reputation and song trend, not track length

The relationship appears weak or close to zero.

4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.

Answer:
By counting the frequency of each artist, we determine who appears most often.
Top artists typically include popular hip-hop performers with large discographies.

The countplot clearly shows which artists dominate the dataset with the highest number of tracks.

5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.

Answer:
We sort songs by popularity in ascending order and select the first five.

These tracks represent songs with minimal listener engagement, fewer plays, or limited exposure on Spotify.

Each entry includes:

Artist Name

Track Name

Popularity Score

This helps identify underperforming songs.

6. Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.

Answer:
Steps:

Identify the top 5 artists with the highest number of tracks

Compute the average popularity for each

Compare their averages

This analysis highlights which artists consistently produce highly popular tracks, rather than relying on a single hit.

The artist with the highest average popularity demonstrates stronger listener preference.

7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.

Answer:
For each of the top 5 artists, we select the track with the highest popularity value.

This gives us:

Artist name

Track with highest popularity

Popularity score

This highlights the standout tracks that contribute to each artist’s overall success.

8. Visualize relationships between multiple numerical variables simultaneously using a pair plot.

Answer:
A pair plot (pairwise scatter plots + distributions) reveals relationships between numerical features such as:

Popularity

Duration (ms)

Insights include:

Whether longer tracks show different popularity ranges

Whether popularity distributions show clustering

Whether any unusual patterns appear

Although relationships are often weak, the visualization helps identify correlations and trends.

9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.

Answer:
Using a box plot grouped by artist, we examine how track durations differ.

Typical findings:

Some artists consistently produce longer tracks

Others prefer shorter, more compact songs

Variability within artists shows their musical style diversity

A violin plot provides deeper insight into distribution density.

This reveals stylistic differences in track length among artists.

10. How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.

Answer:
A swarm plot or violin plot shows the spread of popularity scores for each artist.

Insights:

Some artists have consistently high popularity (tight clusters at upper range)

Others have wide variation due to both hit and average songs

Some artists may have mostly low-popularity tracks

This visualization clearly highlights the popularity performance of each artist and shows whether an artist has stable success or mixed results.

""""
